# %% [markdown]
# <a href="https://colab.research.google.com/github/satomin0718/pictresize/blob/main/3_%E5%8F%AF%E8%A6%96%E5%8C%96_ipynb_%E3%81%AE%E3%82%B3%E3%83%94%E3%83%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 可視化してみよう！<<棒グラフ>>

# %%
import matplotlib.pyplot as plt

x1 = [1, 2, 3, 4, 5, 6, 9] #x1の値（X軸の値
y1 = [4, 7, 2, 4, 7, 8, 3] #y1の値（Y軸の値

#x2 = [2, 4, 6, 8, 10]
#y2 = [5, 6, 2, 6, 2]

# Colors: https://matplotlib.org/api/colors_api.html

plt.bar(x1, y1, label="Pink Bar", color='tab:pink') #棒グラフにする要素を指定
#plt.bar(x2, y2, label="Cyan Bar", color='c')
plt.plot() #棒グラフを表示

plt.xlabel("bar number") #x軸ラベル名の指定
plt.ylabel("bar height") #y軸ラベル名の指定
plt.title("Bar Chart Example")  #グラフのタイトルを指定
plt.legend() #凡例を表示させる
plt.show() #表示する

# %% [markdown]
# 可視化してみよう！<<ヒストグラム>>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Use numpy to generate a bunch of random data in a bell curve around 8.
n = 8 + np.random.randn(1000)

m = [m for m in range(len(n))]
plt.bar(m, n, color='m')
plt.title("Raw Data")
plt.show()

plt.hist(n, bins=20, color='m')
plt.title("Histogram")
plt.show()

plt.hist(n, cumulative=True, bins=20, color='m')
plt.title("Cumulative Histogram")
plt.show()

# %% [markdown]
# 可視化してみよう！<<散布図>>

# %%
import matplotlib.pyplot as plt

x1 = [3, 4, 5]
y1 = [8, 8, 8]

x2 = [5, 6, 7, 8, 9]
y2 = [2, 3, 2, 3, 4]
y3 = [6, 5, 7, 5, 7]

# Markers: https://matplotlib.org/api/markers_api.html

plt.scatter(x1, y1)
plt.scatter(x2, y2, marker='v', color='c')
plt.scatter(x2, y3, marker='^', color='m')
plt.title('Scatter Plot Example')
plt.show()

# %% [markdown]
# 可視化してみよう！<<折れ線グラフ>>

# %%
import matplotlib.pyplot as plt

x  = [1, 2, 3, 4, 5, 6, 7, 8, 9]   # xの値　（X軸の値
y1 = [1, 3, 5, 3, 1, 3, 5, 3, 1]   # y1の値（Y軸の値
y2 = [2, 4, 6, 4, 2, 4, 6, 4, 2]   # y2の値（Y軸の値
y3 = [3, 5, 7, 5, 3, 5, 1, 5, 3]   # y3の値（Y軸の値
plt.plot(x, y1, label="line L")    # xとy1を凡例：「line L」としてプロットする
plt.plot(x, y2, label="line M")    # xとy2を凡例：「line M」としてプロットする
plt.plot(x, y3, label="line H")    # xとy3を凡例：「line H」としてプロットする

plt.xlabel("x axis")   # x軸ラベル名の指定
plt.ylabel("y axis")   # y軸ラベル名の指定
plt.title("Line Graph Example")   # グラフのタイトルを指定
plt.legend() #　凡例を表示させる
plt.show() # 表示する

# %% [markdown]
# 可視化してみよう！<<円グラフ>>

# %%
import matplotlib.pyplot as plt

labels = 'S1', 'S2', 'S3'
sections = [10, 20, 30]
colors = ['#FDD82F', 'tab:pink', 'c']

plt.pie(sections, labels=labels, colors=colors,
        startangle=90,
        explode = (0, 0.1, 0),
        autopct = '%1.2f%%')

plt.axis('equal') # Try commenting this out.
plt.title('Pie Chart Example')
plt.show()
