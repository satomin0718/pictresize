# %% [markdown]
# <a href="https://colab.research.google.com/github/satomin0718/pictresize/blob/main/1_%E5%9B%9B%E5%89%87%E6%BC%94%E7%AE%97_ipynb_%E3%81%AE%E3%82%B3%E3%83%94%E3%83%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 足し算(加算)　 +演算子

# %%
3 + 5
# Out:
# 8

# %% [markdown]
# 引き算(減算)： -演算子

# %%
8 - 2

# %% [markdown]
# 掛け算(乗算)：*演算子

# %%
5 * 4

# %% [markdown]
# 割り算(除算)： /演算子

# %%
25 / 5

# %% [markdown]
# 割り算(除算)_切り捨て：//演算子

# %%
25 // 3

# %% [markdown]
#  割り算(剰余)_除算の余り：%演算子

# %%
10 % 3

# %% [markdown]
# べき乗：**演算子

# %%
3 ** 2
